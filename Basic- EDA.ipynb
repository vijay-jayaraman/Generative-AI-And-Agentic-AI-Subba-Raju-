# %% [markdown]
# <div align="center">
#
# # **Exploratory Data Analysis (EDA)**
# </div>
# <div align="right">
#
# ### *-From Reading Data to Understanding It*
# </div>

# %% [markdown]
# ## **Introduction**
# Exploratory Data Analysis (EDA) is the process of summarizing, visualizing, and understanding datasets before applying advanced modeling.
#
# We will cover:
# - **Iteration-1:** Data Loading & Basic Exploration
# - **Iteration-2:** Data Visualization & Relationship Analysis

# %% [markdown]
# <div align="center">
#
#  # **Exploratory Data Analysis (EDA) — Iteration 1**
#  ### *Step-by-Step Execution with Professional Insights*
#
# </div>

# %% [markdown]
# ### Step 1 — Read and print data
# **Objective:** We load the dataset into a Pandas DataFrame so that we can perform EDA operations.
#
# **Insight:**
# - `pd.read_csv()` reads CSV files into a DataFrame (table-like structure).
# - `.head()` displays the first 5 rows (you can pass a number to view more rows, e.g., `.head(10)`).
# This helps verify if the dataset has been read correctly.

# %%
import pandas as pd
import seaborn as sns

# Load dataset
df = sns.load_dataset("iris")

# Display first 5 rows (by default is five)
df.head() # We can costum to no of outputs we requide -- head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Step 2 — Shape of the Data
#
# **Objective:** Find the number of rows and columns in the dataset.
#
# **Insight:**
# - `df.shape` → Returns `(rows, columns)`.
# - `len(df)` → Returns number of rows.

# %%
df.shape
# Out:
# (150, 5)

# %%
len(df)
# Out:
# 150

# %% [markdown]
# ### Step 3 — Dataset Information
#
# **Objective:** Get column names, data types, and non-null counts.
#
# **Insight:**
# - `df.info()` → Detailed structure.
# - `df.dtypes` → Only data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Step 4 — Find and Remove Duplicates
#
# **Objective:** Check if the dataset contains duplicate rows.
#
# **Insight:**
# - `df.duplicated().sum()` → Counts duplicates.
# - `df.drop_duplicates(inplace=True)` → Removes duplicates permanently.

# %%
# It show the number of dupilates present in the data set
duplicates = df.duplicated().sum() 
print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 0

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Step 5 — Basic Statistics for Numerical Data
#
# **Objective:** Summarize data like mean, median, std, min, max, etc.
#
# **Insight:**
# - `.describe()` → Summary for numeric columns by default.
# - `.describe(include='all')` → Summary for all columns.
# - `.describe().T` → Transposed for readability.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.843624     3.059732      3.748993     1.194631
# std        0.830851     0.436342      1.767791     0.762622
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.300000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Step 6 — Rename Columns
#
# **Objective:** Make column names cleaner and more consistent.
#
# **Insight:**
# - `df.rename(columns={'old':'new'}, inplace=True)`
# - `.str.replace(" ", "_")` → Useful for replacing spaces in column names.

# %%
# Example: Rename petal_length to petal_len
df.rename(columns={'petal_length':'petal_len'}, inplace=True)

df.head()
# Out:
#    sepal_length  sepal_width  petal_len  petal_width species
# 0           5.1          3.5        1.4          0.2  setosa
# 1           4.9          3.0        1.4          0.2  setosa
# 2           4.7          3.2        1.3          0.2  setosa
# 3           4.6          3.1        1.5          0.2  setosa
# 4           5.0          3.6        1.4          0.2  setosa

# %% [markdown]
# ### Step 7 — Missing Values
#
# **Objective:** Check for missing (NaN) values.
#
# **Insight:**
# - `.isnull().sum()` → Count missing values per column.
# - `.isnull().mean()*100` → Missing percentage.

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_len       0
# petal_width     0
# species         0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# sepal_length    0.0
# sepal_width     0.0
# petal_len       0.0
# petal_width     0.0
# species         0.0
# dtype: float64

# %% [markdown]
# ### Step 8 — Statistics for Categorical Columns
#
# **Objective:** Analyze categorical variables.
#
# **Insight:**
# - `.describe(include=['object'])` → Summary for string columns.
# - `.nunique()` → Count unique values per column.

# %%
df.describe(include=['object'])
# Out:
#        species
# count      149
# unique       3
# top     setosa
# freq        50

# %% [markdown]
# ### Step 9 — Count Analysis for Categorical Columns
#
# **Objective:** Count frequency of each category.
#
# **Insight:**
# - `.value_counts()` → Count occurrences.
# - `.value_counts(normalize=True)` → Percentage form.

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     49
# Name: count, dtype: int64

# %% [markdown]
# <div align="center">
#
# # **Exploratory Data Analysis (EDA) — Iteration 2**
# ### *Univariate, Bivariate, and Multivariate Analysis with Professional Insights*
#
# </div>

# %%
# Import required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load example dataset (Iris)
df = sns.load_dataset("iris")

# Display first 5 rows
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## **Step 1 — Univariate Analysis**
# 📌 **Purpose:**
# Analyze one variable at a time to understand its distribution, spread, and possible outliers.
#
# We’ll cover:
# - **Numerical variables:** Histogram & Boxplot
# - **Categorical variables:** Countplot & Pie Chart

# %% [markdown]
# #### **Univariate: Numerical :** Histogram & Boxplot

# %%
# Numerical columns
num_cols = df.select_dtypes(include='number').columns

# Histogram for numerical columns
for col in num_cols:
    plt.figure(figsize=(6,4)) # We can add subplot
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# #### kde=True → Adds a smooth density curve.

# %%
# Boxplot for numerical columns
for col in num_cols:
    plt.figure(figsize=(6,4))  # We can add subplot
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [markdown]
# #### Boxplots are quick to detect outliers visually.

# %% [markdown]
# #### **Univariate: Categorical :**  Countplot & Pie Chart

# %%
# Categorical columns
cat_cols = df.select_dtypes(include='object').columns

# Countplot for categorical columns
for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=df[col], palette='Set2')
    plt.title(f'Count of {col}')
    plt.show()
# Out:
# C:\Users\devag\AppData\Local\Temp\ipykernel_10472\1920293746.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette='Set2')

# %%
# Pie chart for categorical columns
for col in cat_cols:
    plt.figure(figsize=(6,4))
    df[col].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel"))
    plt.title(f'Pie Chart of {col}')
    plt.ylabel("")
    plt.show()

# %% [markdown]
# #### autopct='%1.1f%%' → shows percentages in pie chart.
#
# #### startangle=90 → makes pie charts start from the top for symmetry.

# %% [markdown]
# ## **Step 2 — Bivariate Analysis**
# 📌 **Purpose:**
# Examine the relationship between two variables.
#
# We’ll cover:
# - **Numerical & Categorical:** Boxplot
# - **Categorical & Categorical:** Countplot with hue
# - **Numerical & Numerical:** Scatterplot, LM plot

# %% [markdown]
# #### **Numerical & Categorical**

# %%
# Example: Petal length by species
sns.boxplot(x='species', y='petal_length', data=df, palette='Set3')
plt.title('Petal Length by Species')
plt.show()
# Out:
# C:\Users\devag\AppData\Local\Temp\ipykernel_10472\3008639433.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='petal_length', data=df, palette='Set3')

# %% [markdown]
# #### **Categorical & Categorical**

# %%
# Create petal width category
df['petal_width_cat'] = pd.cut(df['petal_width'], bins=[0,0.5,1.5,2.5], labels=['Small','Medium','Large'])

# Countplot with hue
sns.countplot(x='species', hue='petal_width_cat', data=df, palette='coolwarm')
plt.title('Species vs Petal Width Category')
plt.show()

# %% [markdown]
# #### **Numerical & Numerical**

# %%
# Scatter plot
sns.scatterplot(x='sepal_length', y='petal_length', hue='species', data=df, palette='viridis')
plt.title('Sepal Length vs Petal Length')
plt.show()

# Regression plot
sns.lmplot(x='sepal_length', y='petal_length', hue='species', data=df, height=5, aspect=1.2)

# %% [markdown]
# #### lmplot adds regression lines to detect trends.
#
# #### Scatter plots show clusters & relationships.

# %% [markdown]
# ## **Step 3 — Multivariate Analysis**
# 📌 **Purpose:**
# Study relationships between 3 or more variables at the same time.
# We’ll use **Pairplot** and **Correlation Heatmap**.

# %%
# Pairplot
sns.pairplot(df, hue='species', palette='husl')
plt.show()

# %% [markdown]
# ### * Pairplots are great for detecting clusters and correlations.

# %%
# Correlation heatmap (only numeric columns)
plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Heatmaps are used for feature selection in ML.

# %%
# Correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 3
#       1 # Correlation heatmap
#       2 plt.figure(figsize=(8,6))
# ----> 3 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#       4 plt.title('Correlation Heatmap')
#       5 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...
